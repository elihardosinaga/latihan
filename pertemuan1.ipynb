# %%
print("hello world")
# Out:
# hello world

# %%
nama = "agung" # kutip dua = string
print(nama)
del nama # menghapus variabel
print(nama)
# Out:
# agung
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2 print(nama)
#       3 del nama # menghapus variabel
# ----> 4 print(nama)
#
# NameError: name 'nama' is not defined

# %% [markdown]
# TIPE DATA ANGKA

# %%
angka_int = 10 # tipe data integer
angka_float = 10.5 # tipe data float

print(angka_int)
print(angka_float)
# Out:
# 10
# 10.5

# %% [markdown]
# TIPE DATA TULISAN

# %%
kata_string = "test123"  # string
kata_char = 'C' # char

test = "aku 'halo'"
test2 = '"halo"'

# %% [markdown]
# BOOLEAN

# %%
bool_true = True # true = 1
bool_false = False # false = 0

# %% [markdown]
# KONVERSI

# %%
angka = 10
print("tipe data angka :", type(angka))
angka_float = float(angka)
print("angka =", angka)
print("angka float =", angka_float)
print("tipe data angka float :", type(angka_float))
print("boolean true = ", bool_true)
print("boolean angka : ", bool(0))
# Out:
# tipe data angka : <class 'int'>
# angka = 10
# angka float = 10.0
# tipe data angka float : <class 'float'>
# boolean true =  True
# boolean angka :  False

# %% [markdown]
# ASSIGNMENT

# %%
provinsi = "bali"
print("provinsi =", provinsi)
# Out:
# provinsi = bali

# %%
angka = 3 + 4 + 5
print(angka)
# Out:
# 12
